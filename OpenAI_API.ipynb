# %% [markdown]
# <a href="https://colab.research.google.com/github/sssmin2/jinung_sw/blob/main/OpenAI_API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from openai import OpenAI, APIError
import time

OPENAI_API_KEY = ""

client = OpenAI(api_key=OPENAI_API_KEY)

max_retries = 3
retry_delay = 5 # seconds

# %%
max_retries = 3
retry_delay = 2

for attempt in range(max_retries):
    try:
        response = client.chat.completions.create(
            model="gpt-3.5-turbo-0125",
            messages=[
                {"role": "system", "content": "You are a knowledgeable assistant."},
                {"role": "assistant", "content": "Answer in Korean."},
                {"role": "user", "content": "What are the health benefits of regular exercise?"}
            ]
        )
        print(response.choices[0].message.content)
        break
    except APIError as e:
        print(f"API error occurred: {e}")
        if attempt < max_retries - 1:
            print(f"Retrying in {retry_delay} seconds...")
            time.sleep(retry_delay)
        else:
            print("Max retries reached. Giving up.")
# Out:
# 정기적인 운동의 건강상의 이점은 많습니다. 일반적인 이점으로는 체중 관리, 심혈관 건강 향상, 근육 강화, 스트레스 감소, 면역력 증진 등이 있습니다. 또한 운동은 우울증 예방, 뇌 기능 향상, 잠의 질 향상 등의 심리적인 면에서도 유익합니다. 결론적으로, 정기적인 운동은 신체적, 정신적 건강을 향상시키는데 큰 도움이 됩니다.

# %%
from openai import OpenAI, APIError
import time

max_retries = 3
retry_delay = 2

for attempt in range(max_retries):
    try:
        response = client.chat.completions.create(
            model="gpt-3.5-turbo-0125",
            messages=[
                {"role": "system", "content": "You are a knowledgeable assistant."},
                {"role": "assistant", "content": "Answer in Korean."},
                {"role": "user", "content": "What are the health benefits of regular exercise?"}
            ],
            max_tokens=200
        )
        print(response.choices[0].message.content)
        break
    except APIError as e:
        print(f"API error occurred: {e}")
        if attempt < max_retries - 1:
            print(f"Retrying in {retry_delay} seconds...")
            time.sleep(retry_delay)
        else:
            print("Max retries reached. Giving up.")
# Out:
# 정기적인 운동은 건강에 많은 이점을 줍니다. 대표적인 이점으로는 다음과 같습니다:
# 1. 체중조절: 운동을 통해 체지방을 감소시키고 근육을 강화하여 체중을 조절할 수 있습니다.
# 2. 심혈관 건강: 유산소 운동은 심혈관 기능을 강화하고 심장 질환이나 고혈압 위험을 줄일 수 있습니다.
# 3. 스트레스 감소: 운동은 스트레스 호르몬의 분비를 줄이고 행복호르몬인

# %% [markdown]
# #### temp=0.1

# %%
for attempt in range(max_retries):
    try:
        response = client.chat.completions.create(
            model="gpt-3.5-turbo-0125",
            messages=[
                {"role": "system", "content": "You are a knowledgeable assistant."},
                {"role": "assistant", "content": "Answer in Korean."},
                {"role": "user", "content": "What are the health benefits of regular exercise?"}
            ],
            temperature=0.1
        )
        print(response.choices[0].message.content)
        break
    except APIError as e:
        print(f"API error occurred: {e}")
        if attempt < max_retries - 1:
            print(f"Retrying in {retry_delay} seconds...")
            time.sleep(retry_delay)
        else:
            print("Max retries reached. Giving up.")
# Out:
# 정기적인 운동은 건강에 많은 이점을 줍니다. 몇 가지 중요한 이점은 다음과 같습니다:
#
# 1. 체중 관리: 운동은 체중을 조절하고 유지하는 데 도움을 줍니다.
# 2. 심혈관 건강: 운동은 심장과 혈관 건강을 증진시키고 심혈관 질환의 위험을 줄여줍니다.
# 3. 근육 강화: 운동은 근육을 강화하고 유지하는 데 도움을 줍니다.
# 4. 스트레스 감소: 운동은 스트레스를 줄이고 신체와 정신적인 건강을 증진시킵니다.
# 5. 면역력 강화: 운동은 면역 시스템을 강화하여 감염병에 대한 verall적인 저항력을 높여줍니다.
#
# 이러한 이점들은 정기적인 운동을 통해 얻을 수 있으며, 건강한 삶을 유지하는 데 중요합니다.

# %% [markdown]
# #### temp=0.9

# %%
for attempt in range(max_retries):
    try:
        response = client.chat.completions.create(
            model="gpt-3.5-turbo-0125",
            messages=[
                {"role": "system", "content": "You are a knowledgeable assistant."},
                {"role": "assistant", "content": "Answer in Korean."},
                {"role": "user", "content": "What are the health benefits of regular exercise?"}
            ],
            temperature=0.9
        )
        print(response.choices[0].message.content)
        break
    except APIError as e:
        print(f"API error occurred: {e}")
        if attempt < max_retries - 1:
            print(f"Retrying in {retry_delay} seconds...")
            time.sleep(retry_delay)
        else:
            print("Max retries reached. Giving up.")
# Out:
# 규칙적인 운동을 하는 것은 건강에 많은 이점을 줍니다. 이는 체지방 감소, 근육 강화, 심혈관 건강 증진, 신체 기능 향상, 스트레스 감소, 우울증 완화 등 다양한 이점을 포함합니다. 또한 운동은 대사를 촉진하고 면역력을 향상시키는데 도움을 줄 수 있습니다. 규칙적인 운동은 전반적인 건강을 향상시키는데 중요한 역할을 합니다.

# %% [markdown]
# #### seed=42

# %%
import time
from openai import OpenAI, APIError

max_retries = 3
retry_delay = 5

for attempt in range(max_retries):
  try:
    response = client.chat.completions.create(
        model="gpt-3.5-turbo-0125",
        messages=[
            {"role": "system", "content": "You are a knowledgeable assistant."},
            {"role": "assistant", "content": "Answer in Korean."},
            {"role": "user", "content": "What are the health benefits of regular exercise?"}
        ]
    )
    print(response.choices[0].message.content)
    break
  except client.error.APIError as e:
    print(f"API error occurred: {e}")
    if attempt < max_retries - 1:
      print(f"Retrying in {retry_delay} seconds...")
      time.sleep(retry_delay)
    else:
      print("Max retries reached. Giving up.")
# Out:
# 규칙적인 운동은 건강에 많은 이점을 제공합니다. 운동을 통해 심혈관 건강이 향상되고 체지방이 감소할 뿐만 아니라 근육 강화, 관절 유연성 향상, 신체 기능 개선, 스트레스 감소 및 우울증 완화 등 다양한 긍정적인 영향을 끼칩니다. 또한, 정기적인 운동은 만성 질병 예방에 도움이 되며 일반적인 건강 상태를 유지하는 데 도움을 줍니다.

# %% [markdown]
# #### Embeddings

# %%
from openai import OpenAI
import numpy as np

client = OpenAI(api_key=OPENAI_API_KEY)

def get_embeddings(texts):
  response = client.embeddings.create(
      input=texts,
      model="text-embedding-ada-002"
  )
  embeddings = [item.embedding for item in response.data]
  return embeddings
color_words = ["red", "blue", "yellow", "green", "violet", "cyan", "black", "white"]

color_embeddings=get_embeddings(color_words)

for word, embedding in zip(color_words, color_embeddings):
    print(f"{word} : {embedding[::5]}...")
    print(len(embedding))
# Out:
121016860008, 0.014334344305098057, -0.0014705897774547338, 0.019362477585673332, -0.022446027025580406, -1.5002143300080206e-05, 0.015514982864260674, -0.00016700396372471005, 0.005587199702858925, 0.016917860135436058, 0.02020975947380066, -0.014667700976133347, -0.004482955206185579, -0.017306776717305183, -0.004607963841408491, 0.0044447579421103, -0.019556934013962746, -0.016431715339422226, -0.020362546667456627, 0.0016936959000304341, 0.006573380436748266, 0.011417471803724766, 0.025349009782075882, -0.003069660859182477, 0.028668688610196114, 0.04036395624279976, -0.010347952134907246, 0.009764577262103558, 0.018640203401446342, 0.024696186184883118, -0.006583797745406628, -0.008410315029323101, -0.0005382323870435357, 0.008438095450401306, 0.009333991445600986, 0.01858464442193508, -0.005538585130125284, -0.016640063375234604, 0.022362688556313515, 0.014403793960809708, 0.01160498522222042, -0.0030939681455492973, -0.0035627512261271477, -0.0006476151174865663, 0.020251428708434105, 0.010389621369540691, -0.02654353901743889, 0.004694775678217411, -0.0113341324031353, -0.015181626193225384, -0.010118769481778145, -0.0007135919877327979, -0.0027519301511347294, -0.03322456404566765, -0.0047989496961236, -0.00275713880546391, -0.020431997254490852, -0.028779808431863785, -0.0013395041460171342, 0.0015330942114815116, 0.019293026998639107, -0.00952844973653555, -0.021584855392575264, 0.016959529370069504, 0.005549002438783646, 0.009535394608974457, 0.027557499706745148, 0.0025748342741280794, 0.007833885960280895, 0.0033353047911077738, -0.0209320317953825, -0.008986745029687881, -0.013945427723228931, -0.008257526904344559, -0.010959106497466564, -0. ...
# 1536

# %% [markdown]
# #### Fine-tuning

# %%
from openai import OpenAI
import numpy as np

client = OpenAI(api_key=OPENAI_API_KEY)

# %%
response = client.files.create(
    file=open("mydata.jsonl","rb"),
    purpose='fine-tune'
)
file_id = response.id
print(f"Uploaded file ID: {file_id}")
# Out:
# Uploaded file ID: file-8jHriVwJpbAWomSXnBKVoa

# %%
response=client.fine_tuning.jobs.create(
    training_file=file_id,
    model='gpt-3.5-turbo'
)
fine_tune_id = response.id
print(f"Fine-tune job ID: {fine_tune_id}")
# Out:
# Fine-tune job ID: ftjob-Iej9zT01pzNCASr2RFyZP6og

# %%
while True:
  response = client.fine_tuning.jobs.retrieve(fine_tune_id)
  status = response.status
  if status in ['succeeded', 'failed']:
    break
  print(f"Fine-tune job status: {status}")
  time.sleep(60)
# Out:
# Fine-tune job status: running
# Fine-tune job status: running
# Fine-tune job status: running
# Fine-tune job status: running
# Fine-tune job status: running
# Fine-tune job status: running
# Fine-tune job status: running
# Fine-tune job status: running
# Fine-tune job status: running
# Fine-tune job status: running
# Fine-tune job status: running
# Fine-tune job status: running
# Fine-tune job status: running
# Fine-tune job status: running
# Fine-tune job status: running
# Fine-tune job status: running
# Fine-tune job status: running
# Fine-tune job status: running
# Fine-tune job status: running
# Fine-tune job status: running

# %%
if status == "succeeded":
    ft_model = getattr(response, "fine_tuned_model", None)
    if not ft_model:
        print("Fine-tuned model ID not found.")
    else:
        completion = client.chat.completions.create(
            model=ft_model,
            messages=[
                {"role": "user", "content": "Translate the following English text to French: 'Good night'"}
            ],
            max_tokens=50
        )
        print("Fine-tuned output:", completion.choices[0].message["content"])
else:
    print("Fine-tune job failed.")
# Out:
# Fine-tuned model ID not found.

# %% [markdown]
# #### Edit

# %%
def edit_text(input_text, instruction):
  response = client.chat.completions.create(
      model="gpt-3.5-turbo-0125",
      messages=[
          {"role": "system", "content": "You are a helpful assistant that edits text."},
          {"role": "user", "content": f"Please edit the following text '{input_text}'. Instruction: {instruction}"}
      ]
  )
  return response.choices[0].message.content

input_text = "The quick brown fox jumps over the lazy dog."
instruction = "Change 'fox' to 'cat' and change the tense to past."

edited_text = edit_text(input_text, instruction)
print(f"Edited Text: {edited_text}")
# Out:
# Edited Text: "The quick brown cat jumped over the lazy dog."

# %% [markdown]
# #### Moderation

# %%
def moderate_text(input_text):
  response = client.moderations.create(
      input=input_text,
      model="omni-moderation-latest"
  )
  return response
input_texts = [
    "I want to harm myself.",
    "You are an amazing person!",
    "Let's meet as 8 PM.",
    "I hate you and I want to hurt you."
]

for text in input_texts:
    moderation_result = moderate_text(text)
    print(f"Input Text: {text}")
    print(f"Moderation Result: {moderation_result}")
    print("-" * 40)
# Out:
# Input Text: I want to harm myself.
# Moderation Result: ModerationCreateResponse(id='modr-3299', model='omni-moderation-latest', results=[Moderation(categories=Categories(harassment=False, harassment_threatening=False, hate=False, hate_threatening=False, illicit=False, illicit_violent=False, self_harm=True, self_harm_instructions=False, self_harm_intent=True, sexual=False, sexual_minors=False, violence=True, violence_graphic=False, harassment/threatening=False, hate/threatening=False, illicit/violent=False, self-harm/intent=True, self-harm/instructions=False, self-harm=True, sexual/minors=False, violence/graphic=False), category_applied_input_types=CategoryAppliedInputTypes(harassment=['text'], harassment_threatening=['text'], hate=['text'], hate_threatening=['text'], illicit=['text'], illicit_violent=['text'], self_harm=['text'], self_harm_instructions=['text'], self_harm_intent=['text'], sexual=['text'], sexual_minors=['text'], violence=['text'], violence_graphic=['text'], harassment/threatening=['text'], hate/threatening=['text'], illicit/violent=['text'], self-harm/intent=['text'], self-harm/instructions=['text'], self-harm=['text'], sexual/minors=['text'], violence/graphic=['text']), category_scores=CategoryScores(harassment=0.0005700198491106524, harassment_threatening=0.0007684985562636434, hate=1.7952796934677738e-05, hate_threatening=8.61465062380632e-06, illicit=0.005282392090762785, illicit_violent=2.453694805426225e-05, self_harm=0.9745672565469147, self_harm_instructions=0.00028151729221049604, self_harm_intent=0.9885491614739444, sexual=8.559006367452268e-05, sexual_minors=6.205049602300744e-06, violence=0.40259301082576604, violence_graphic=0.0016082622770097628, harassment/threatening=0.0007684985562636434, hate/threatening=8.61465062380632e-06, illicit/violent=2.453694805426225e-05, self-harm/intent=0.9885491614739444, self-harm/instructions=0.00028151729221049604, self-harm=0.9745672565469147, sexual/minors=6.205049602300744e-06, violence/graphic=0.0016082622770097628), flagged=True)])
# ----------------------------------------
# Input Text: You are an amazing person!
# Moderation Result: ModerationCreateResponse(id='modr-7956', model='omni-moderation-latest', results=[Moderation(categories=Categories(harassment=False, harassment_threatening=False, hate=False, hate_threatening=False, illicit=False, illicit_violent=False, self_harm=False, self_harm_instructions=False, self_harm_intent=False, sexual=False, sexual_minors=False, violence=False, violence_graphic=False, harassment/threatening=False, hate/threatening=False, illicit/violent=False, self-harm/intent=False, self-harm/instructions=False, self-harm=False, sexual/minors=False, violence/graphic=False), category_applied_input_types=CategoryAppliedInputTypes(harassment=['text'], harassment_threatening=['text'], hate=['text'], hate_threatening=['text'], illicit=['text'], illicit_violent=['text'], self_harm=['text'], self_harm_instructions=['text'], self_harm_intent=['text'], sexual=['text'], sexual_minors=['text'], violence=['text'], violence_graphic=['text'], harassment/threatening=['text'], hate/threatening=['text'], illicit/violent=['text'], self-harm/intent=['text'], self-harm/instructions=['text'], self-harm=['text'], sexual/minors=['text'], violence/graphic=['text']), category_scores=CategoryScores(harassment=0.0006620400451320043, harassment_threatening=1.0889691002655445e-05, hate=6.205049602300744e-06, hate_threatening=1.602810987828144e-07, illicit=6.40200641038395e-06, illicit_violent=4.331903899346328e-06, self_harm=1.15017355457e-05, self_harm_instructions=1.1300808333434096e-06, self_harm_intent=5.225226840386988e-06, sexual=1.15919343186331e-05, sexual_minors=1.3846004563753396e-06, violence=0.0005335820331640444, violence_graphic=4.98595821272702e-06, harassment/threatening=1.0889691002655445e-05, hate/threatening=1.602810987828144e-07, illicit/violent=4.331903899346328e-06, self-harm/intent=5.225226840386988e-06, self-harm/instructions=1.1300808333434096e-06, self-harm=1.15017355457e-05, sexual/minors=1.3846004563753396e-06, violence/graphic=4.98595821272702e-06), flagged=False)])
# ----------------------------------------
# Input Text: Let's meet as 8 PM.
# Moderation Result: ModerationCreateResponse(id='modr-6037', model='omni-moderation-latest', results=[Moderation(categories=Categories(harassment=False, harassment_threatening=False, hate=False, hate_threatening=False, illicit=False, illicit_violent=False, self_harm=False, self_harm_instructions=False, self_harm_intent=False, sexual=False, sexual_minors=False, violence=False, violence_graphic=False, harassment/threatening=False, hate/threatening=False, illicit/violent=False, self-harm/intent=False, self-harm/instructions=False, self-harm=False, sexual/minors=False, violence/graphic=False), category_applied_input_types=CategoryAppliedInputTypes(harassment=['text'], harassment_threatening=['text'], hate=['text'], hate_threatening=['text'], illicit=['text'], illicit_violent=['text'], self_harm=['text'], self_harm_instructions=['text'], self_harm_intent=['text'], sexual=['text'], sexual_minors=['text'], violence=['text'], violence_graphic=['text'], harassment/threatening=['text'], hate/threatening=['text'], illicit/violent=['text'], self-harm/intent=['text'], self-harm/instructions=['text'], self-harm=['text'], sexual/minors=['text'], violence/graphic=['text']), category_scores=CategoryScores(harassment=9.915273115920183e-06, harassment_threatening=3.4808121961114687e-06, hate=2.88571183887091e-06, hate_threatening=2.4824800371656586e-07, illicit=1.1959857805023158e-05, illicit_violent=1.1959857805023158e-05, self_harm=3.944258675190877e-06, self_harm_instructions=1.7502925788778209e-06, self_harm_intent=3.0718185454758057e-06, sexual=2.234163601827719e-05, sexual_minors=2.0462932829931794e-06, violence=0.000493111798506495, violence_graphic=1.3846004563753396e-06, harassment/threatening=3.4808121961114687e-06, hate/threatening=2.4824800371656586e-07, illicit/violent=1.1959857805023158e-05, self-harm/intent=3.0718185454758057e-06, self-harm/instructions=1.7502925788778209e-06, self-harm=3.944258675190877e-06, sexual/minors=2.0462932829931794e-06, violence/graphic=1.3846004563753396e-06), flagged=False)])
# ----------------------------------------
# Input Text: I hate you and I want to hurt you.
# Moderation Result: ModerationCreateResponse(id='modr-7802', model='omni-moderation-latest', results=[Moderation(categories=Categories(harassment=True, harassment_threatening=True, hate=False, hate_threatening=False, illicit=False, illicit_violent=False, self_harm=False, self_harm_instructions=False, self_harm_intent=False, sexual=False, sexual_minors=False, violence=True, violence_graphic=False, harassment/threatening=True, hate/threatening=False, illicit/violent=False, self-harm/intent=False, self-harm/instructions=False, self-harm=False, sexual/minors=False, violence/graphic=False), category_applied_input_types=CategoryAppliedInputTypes(harassment=['text'], harassment_threatening=['text'], hate=['text'], hate_threatening=['text'], illicit=['text'], illicit_violent=['text'], self_harm=['text'], self_harm_instructions=['text'], self_harm_intent=['text'], sexual=['text'], sexual_minors=['text'], violence=['text'], violence_graphic=['text'], harassment/threatening=['text'], hate/threatening=['text'], illicit/violent=['text'], self-harm/intent=['text'], self-harm/instructions=['text'], self-harm=['text'], sexual/minors=['text'], violence/graphic=['text']), category_scores=CategoryScores(harassment=0.8057718838706006, harassment_threatening=0.5509624992902102, hate=0.0011864146960012469, hate_threatening=5.527786369235996e-05, illicit=0.020043798361113124, illicit_violent=0.0020194050134869097, self_harm=0.0005302147677935735, self_harm_instructions=0.0002145314506303538, self_harm_intent=0.0002763292760766304, sexual=0.0007067749478525128, sexual_minors=7.722191834067996e-06, violence=0.8507924307636365, violence_graphic=4.373344035182828e-05, harassment/threatening=0.5509624992902102, hate/threatening=5.527786369235996e-05, illicit/violent=0.0020194050134869097, self-harm/intent=0.0002763292760766304, self-harm/instructions=0.0002145314506303538, self-harm=0.0005302147677935735, sexual/minors=7.722191834067996e-06, violence/graphic=4.373344035182828e-05), flagged=True)])
# ----------------------------------------

# %% [markdown]
# #### Images

# %%
import requests
from PIL import Image
from io import BytesIO

def generate_image(prompt):
    response = client.images.generate(
        prompt=prompt,
        n=1,
        size="1024x1024"
    )
    image_url = response.data[0].url
    return image_url
def save_image(image_url, filename):
    response = requests.get(image_url)
    image=Image.open(BytesIO(response.content))
    image.save(filename)

prompt = "A futcuristic cityscape at sunset"

image_url = generate_image(prompt)
print(f"Image UR: {image_url}")

save_image(image_url, "generated_image.png")
print("Image saved as generated_image.png")
# Out:
# Image UR: https://oaidalleapiprodscus.blob.core.windows.net/private/org-QCpPbrvbucGS49hYw9tpZAvm/user-mIRxSCQK1QATg3XppRHroiss/img-X0ua3i1HVvAFMyC78BIFFCVR.png?st=2025-11-25T04%3A54%3A38Z&se=2025-11-25T06%3A54%3A38Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=0e2a3d55-e963-40c9-9c89-2a1aa28cb3ac&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-11-25T04%3A24%3A59Z&ske=2025-11-26T04%3A24%3A59Z&sks=b&skv=2024-08-04&sig=c7ZLfyQFv%2BeobgPbAMwthmXM2dW5A1HRy0ydq0Ba6yY%3D
# Image saved as generated_image.png

# %%
import requests
from PIL import Image
from io import BytesIO

def generate_image(prompt):
    response = client.images.generate(
        model="dall-e-3",
        prompt="a white siamese cat",
        n=1,
        size="1024x1024",
        quality="standard"
    )
    image_url = response.data[0].url
    return image_url
def save_image(image_url, filename):
    response = requests.get(image_url)
    image=Image.open(BytesIO(response.content))
    image.save(filename)

image_url = generate_image(prompt)
print(f"Image UR: {image_url}")

save_image(image_url, "siamese cat.png")
print("Image saved as siamese cat.png")
# Out:
# Image UR: https://oaidalleapiprodscus.blob.core.windows.net/private/org-QCpPbrvbucGS49hYw9tpZAvm/user-mIRxSCQK1QATg3XppRHroiss/img-STw1rFpEg02p36heRLTkk9hK.png?st=2025-11-25T05%3A00%3A38Z&se=2025-11-25T07%3A00%3A38Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=c6569cb0-0faa-463d-9694-97df3dc1dfb1&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-11-25T03%3A33%3A45Z&ske=2025-11-26T03%3A33%3A45Z&sks=b&skv=2024-08-04&sig=Xr596S670W90MpBT%2BcVyJrKIFsNgSXPMr6r5AR2D9hw%3D
# Image saved as siamese cat.png

# %%
import requests
from PIL import Image
from io import BytesIO

def generate_image(prompt):
    response = client.images.edit(
        model="dall-e-2",
        image=open("sunlit_lounge.png", "rb"),
        mask=open("mask.png","rb"),
        prompt="A sunlit indoor lounge with a pool containing a flamingo",
        n=1,
        size="1024x1024"
    )
    image_url = response.data[0].url
    return image_url
def save_image(image_url, filename):
    response = requests.get(image_url)
    image=Image.open(BytesIO(response.content))
    image.save(filename)

image_url = generate_image(prompt)
print(f"Image UR: {image_url}")

save_image(image_url, "sunlit_mask.png")
print("Image saved as sunlit_mask.png")
# Out:
# Image UR: https://oaidalleapiprodscus.blob.core.windows.net/private/org-QCpPbrvbucGS49hYw9tpZAvm/user-mIRxSCQK1QATg3XppRHroiss/img-J9hfQZuvCnN30wgjSh3kuVb6.png?st=2025-11-25T06%3A46%3A01Z&se=2025-11-25T08%3A46%3A01Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=38e27a3b-6174-4d3e-90ac-d7d9ad49543f&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-11-25T07%3A39%3A30Z&ske=2025-11-26T07%3A39%3A30Z&sks=b&skv=2024-08-04&sig=xjqNi4ZcDtT%2BQ%2BHmJF6wfNMD%2B8P0eHIZ2Kn2NaBu4W4%3D
# Image saved as sunlit_mask.png

# %% [markdown]
# #### codex

# %%
def generate_code(prompt, model="gpt-3.5-turbo", max_tokens=1000):
    try:
        response = client.chat.completions.create(
            model=model,
            messages=[{"role": "user", "content": prompt}],
            max_tokens=max_tokens,
            temperature=0,
            n=1,
            stop=None
        )
        code = response.choices[0].message.content
        return code
    except Exception as e:
        print(f"An error occurred: {str(e)}")
        return None

prompt = "Write a C Code that computes Fibonacci number using memorization."

generated_code = generate_code(prompt)

if generated_code:
    print("Generated Code:\n")
    print(generated_code)
else:
    print("Failed to generate code.")
# Out:
# Generated Code:
#
# #include <stdio.h>
#
# int fib(int n, int memo[]) {
#     if (memo[n] != -1) {
#         return memo[n];
#     }
#
#     if (n <= 1) {
#         memo[n] = n;
#     } else {
#         memo[n] = fib(n-1, memo) + fib(n-2, memo);
#     }
#
#     return memo[n];
# }
#
# int main() {
#     int n;
#     printf("Enter the value of n: ");
#     scanf("%d", &n);
#
#     int memo[n+1];
#     for (int i = 0; i <= n; i++) {
#         memo[i] = -1;
#     }
#
#     printf("Fibonacci number at position %d is: %d\n", n, fib(n, memo));
#
#     return 0;
# }

# %% [markdown]
# #### File

# %%
upload_response = client.files.create(
    file=open("king-style-chat.jsonl", "rb"),
    purpose='fine-tune'
)
print("Upload Response:")
print(upload_response)
# Out:
# Upload Response:
# FileObject(id='file-MArZaFuUYebzcP4dVu8o91', bytes=57615, created_at=1764056865, filename='king-style-chat.jsonl', object='file', purpose='fine-tune', status='processed', expires_at=None, status_details=None)

# %%
from httpx import delete
list_response=client.files.list()
print("List Response:")
print(list_response)

file_id = upload_response.id
retrieve_response = client.files.retrieve(file_id)
print("Retrieve Response:")
print(retrieve_response)

delete_response = client.files.delete(file_id)
print("Delete Response:")
print(delete_response)
# Out:
# List Response:
# SyncCursorPage[FileObject](data=[FileObject(id='file-MArZaFuUYebzcP4dVu8o91', bytes=57615, created_at=1764056865, filename='king-style-chat.jsonl', object='file', purpose='fine-tune', status='processed', expires_at=None, status_details=None), FileObject(id='file-QYp2x5nUurAudBzKZ76Wim', bytes=57615, created_at=1764051771, filename='king-style-chat.jsonl', object='file', purpose='fine-tune', status='processed', expires_at=None, status_details=None), FileObject(id='file-AnNpDVTV2knorb7L5K5End', bytes=57615, created_at=1764051730, filename='king-style-chat.jsonl', object='file', purpose='fine-tune', status='processed', expires_at=None, status_details=None), FileObject(id='file-UKBcM1Mb8eLYfaCfdfNBG1', bytes=1984, created_at=1764048212, filename='step_metrics.csv', object='file', purpose='fine-tune-results', status='processed', expires_at=None, status_details=None), FileObject(id='file-8jHriVwJpbAWomSXnBKVoa', bytes=3128, created_at=1764046191, filename='mydata.jsonl', object='file', purpose='fine-tune', status='processed', expires_at=None, status_details=None)], has_more=False, object='list', first_id='file-MArZaFuUYebzcP4dVu8o91', last_id='file-8jHriVwJpbAWomSXnBKVoa')
# Retrieve Response:
# FileObject(id='file-MArZaFuUYebzcP4dVu8o91', bytes=57615, created_at=1764056865, filename='king-style-chat.jsonl', object='file', purpose='fine-tune', status='processed', expires_at=None, status_details=None)
# Delete Response:
# FileDeleted(id='file-MArZaFuUYebzcP4dVu8o91', deleted=True, object='file')

# %% [markdown]
# #### Audio

# %%
def transcribe_audio(file_path, model="whisper-1", response_format="json", temperature=0.1, language=None, prompt=None):
  with open(file_path, "rb") as audio_file:
    response = client.audio.transcriptions.create(
      model=model,
      file=audio_file,
      response_format=response_format,
      temperature=temperature,
      language=language,
      prompt=prompt
    )
  return response

file_path = 'Dracula.mp3'

transcription = transcribe_audio(file_path)
print("Transcription Response:")
print(transcription)
# Out:
# Transcription Response:
# Transcription(text="Now that we've found where the enemy's lurking, nothing can stand in our way. Since we are facing the forces of darkness, we must be the cold light of day. We are the lanterns that burn in the lighthouse. The candles in the crypt. We are the light. Let there be light. This is a war and we must be the victors. There's too much to lose if we fail. We'll cross the seas like a band of crusaders, searching for some precious grail. We are the embers that glow in the winter. The diamonds in the mine. Let's take our torches and pray God will show us a sign. Deep in the darkness night, when there's a spark of hope, we must be points of light. He's in the darkness, bright as the dazzling stars in a different sky. And in our cruelest hour, when hope is gone, we'll raise our heads and we'll turn the odds. When the great battle commences, surely the light will prevail. We will break down his defenses. He will fall. And the sun will rise. Deep in the darkness night, when there's a spark of hope, we must be points of light. He's in the darkness, bright as the dazzling stars in a different sky. And in our cruelest hour, when hope is gone, we'll raise our heads and we'll turn the odds.", logprobs=None, usage=UsageDuration(seconds=116.0, type='duration'))
